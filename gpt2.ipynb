# %%
import gpt_2_simple as gpt2

# %%
# gpt2.download_gpt2(model_name='124M')
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 1.38Git/s]
# Fetching encoder.json: 1.05Mit [00:01, 934kit/s]
# Fetching hparams.json: 1.05Mit [00:00, 5.58Git/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [18:32, 448kit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 7.95Git/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 3.38Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 3.63Mit/s]

# %%
session = gpt2.start_tf_sess()

# %%
gpt2.finetune(session, 'shakespeare.txt', model_name='124M', steps=5)
# Out:
# 2023-12-14 09:52:01.249009: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]
# dataset has 338024 tokens
# Training...
# [1 | 19.11] loss=4.08 avg=4.08
# [2 | 39.29] loss=3.96 avg=4.02
# [3 | 58.75] loss=3.60 avg=3.88
# [4 | 78.34] loss=3.70 avg=3.83
# [5 | 97.89] loss=3.38 avg=3.74
# Saving checkpoint/run1/model-5

# %%
gpt2.generate(session, prefix='Me: Which art in heaven, hallowed be thy name')
# Out:
# Me: Which art in heaven, hallowed be thy name, in thy holy name. Verily I say unto thee, that the name of my father is my first.
#
#
# I: What art thou the first?
#
#
#
#
#
#
#
#
#
#
#
# I: My father is my first,
#
#
#
#
# I: for
# the will of God that he may will make me good;
#
#
# I: for that I am my father.
#
#
#
#
#
#
#
#
#
# I: And to thy father's will,
#
#
# I:
#
#
#
# I:
#
#
#
# I:
#
# I:
#
#
# I:
#
# I:
#
#
# I:
#
# I:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <|endoftext|>http://tvtropes.org/pmwiki/pmwiki.php/Main/BootsOfDiet
#
# Diet:
#
# I'm not going to eat that. I'm not going to eat that.
#
# That's not going to be a problem.
#
# Or I will be a nuisance to you.
#
# That's not going to be a problem.
#
# I'm not going to eat that.
#
# That's not going to be a problem.
#
# I'm not going to eat that.
#
# That's not going to be a problem.
#
# I'm not going to eat that.
# That's not going to be a problem.
#
# I'm not going to eat that.
#
# I'm not going to eat that.
#
# The only way that you can really die without being eaten is if you eat three or more meals of meat
# I'm not going to eat that.
#
# I'm not going to eat that.
#
# That's not going to be a problem.
#
# I'm not going to eat that.
#
# That's not going to be a problem.
#
# I'm not going to eat that.
# That's not going to be a problem.
# I'm not going to eat that.
#
# That's not going to be a problem.
#
# That's not going to be a problem.
# I'm not going to eat that.
#
# That's not going to be a problem.
# I'm not going to eat that.
# That's not going to be a problem.
# You can't eat that.
#
# That's not going to be a problem.
# I'm not going to eat that.
# That's not going to be a problem.
# I'm not going to eat that.
#
# That's not going to be a problem.
# I'm not going to eat that.
#
# That's not going to be a problem.
# I'm not going to eat that.
#
#
# I'm not going to eat that.
#
# That's not going to be a problem.
#
# I'm not going to eat that.
# That's not going to be a problem.
# I'm not going to eat that.
# That's not going to be a problem.
# I'm not going to eat that.
# That's not going to be a problem.
#
#
# I'm not going to eat that.
# That's not going to be a problem.
# I'm not going to eat that.
# That's not going to be a problem.
# I'm not going to eat that.
#
#
# I'm not going to eat that.
# That's not going to be a problem.
# I'm not going to eat that.
#
#
# I'm not going to eat that.
# That's not going to be a problem.
# I'm not going to eat that.
#
#
# I'm not going to eat that.
# That's not going to be a problem.
# I'm not going to eat that.<|endoftext|>One of the biggest changes in the world is the upward trend in China's stock market. The time is now, the most important, time to bear in mind. And, as a matter of fact, the world's stock market is already down.
#
# The world's stock market is down, and the Indian rupee isn't even on the top of the world's indices.
#
# I'm asking this to the world's stock market.
#
# This is not to say, "China is down". It's to say…
# China is down on its stock market, and seeing as the stock market has been rising since early last year, the world's stock market is not going down.
#
# The US stock market is down, and it's not going
